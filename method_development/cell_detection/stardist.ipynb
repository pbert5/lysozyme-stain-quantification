# %%
import tifffile as tiff
import numpy as np
import matplotlib.pyplot as plt

image = tiff.imread('/home/phillip/documents/yen-lab-discussion/rfp/Lyz Fabp1/CDKO 158.1/Jej-3.tif')

dapi = tiff.imread('/home/phillip/documents/yen-lab-discussion/rfp/Lyz Fabp1/CDKO 158.1/Jej-3c1.tif')

# %%
dapi[...,2].shape
# Out:
# (1024, 1024)

# %%
from stardist.models import StarDist2D
#StarDist2D.from_pretrained()
model = StarDist2D.from_pretrained('2D_versatile_fluo')
# Out:
# Found model '2D_versatile_fluo' for 'StarDist2D'.
# Loading network weights from 'weights_best.h5'.
# Loading thresholds from 'thresholds.json'.
# Using default values: prob_thresh=0.479071, nms_thresh=0.3.

# %%
from stardist.data import test_image_nuclei_2d
from stardist.plot import render_label
from csbdeep.utils import normalize
import matplotlib.pyplot as plt

img = dapi[...,2]

labels, _ = model.predict_instances_big(normalize(img), axes='YX', block_size=(256,256), min_overlap=(32,64))

plt.subplot(1,2,1)
plt.imshow(img, cmap="gray")
plt.axis("off")
plt.title("input image")

plt.subplot(1,2,2)
plt.imshow(render_label(labels, img=img))
plt.axis("off")
plt.title("prediction + input overlay")
# Out:
# effective: block_size=(256, 256), min_overlap=(32, 64), context=(96, 96)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[28], line 8
#       4 import matplotlib.pyplot as plt
#       6 img = dapi[...,2]
# ----> 8 labels, _ = model.predict_instances_big(normalize(img), axes='YX', block_size=(256,256), min_overlap=(32,64))
#      10 plt.subplot(1,2,1)
#      11 plt.imshow(img, cmap="gray")
#
# File ~/miniconda3/envs/stardist/lib/python3.11/site-packages/stardist/models/base.py:930, in StarDistBase.predict_instances_big(self, img, axes, block_size, min_overlap, context, labels_out, labels_out_dtype, show_progress, **kwargs)
#     927         print(f"{a}: context of {c} is small, recommended to use at least {o}", flush=True)
#     929 # create block cover
# --> 930 blocks = BlockND.cover(img.shape, axes, block_size, min_overlap, context, grid)
# ...
